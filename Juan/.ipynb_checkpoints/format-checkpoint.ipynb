# %%
import pandas as pd
import numpy as np

data = pd.read_excel("CWD assessment data all years.xlsx")
data
# Out:
#                                            Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                              Year 0        NaN        NaN
# 1                                          LENGTH (m)     Plot 1     Plot 2
# 2                                                Logs         68         53
# 3                                          logs >40cm          2         26
# 4                                              stumps       11.5          5
# 5                                               total       81.5         84
# 6                                                 NaN        NaN        NaN
# 7                                                 NaN        NaN        NaN
# 8                                              Year 6        NaN        NaN
# 9                                                Date      43881      43885
# 10                                         LENGTH (m)     Plot 1     Plot 2
# ...

# %% [markdown]
# # Take total CWD and the treatment applied as the only data

# %%
col_names = np.array(data.iloc[1])[1:]
treatment = ["Gap", "Control", "Radial", "Control", "Radial", "Control", "Radial", "Gap", "Radial", "Gap", "Control", "Gap"]
yr0 = np.array(data.iloc[5])[1:]
yr6 = np.array(data.iloc[14])[1:]

##add fenced or not & type



total = pd.DataFrame(data = [treatment, yr0, yr6], index = ["treatment", "year 0", "year 6"],columns = col_names)


total
# Out:
#           Plot 1   Plot 2  Plot 3   Plot 4  Plot 5   Plot 6  Plot 7 Plot 8  \
# treatment    Gap  Control  Radial  Control  Radial  Control  Radial    Gap
# year 0      81.5       84   261.5    136.5   189.5    122.5     280    239
# year 6     549.5     84.8  2132.7      147   510.5      116   728.9  540.5
#
#            Plot 9 Plot 10  Plot 11 Plot 12
# treatment  Radial     Gap  Control     Gap
# year 0      141.5   155.7    222.5     NaN
# year 6        185   624.5    273.7   810.2

# %%
result = total.T
result["difference"] = result["year 6"] - result["year 0"]
result["stumps_diff"] = result["stumps6"] - result["stumps0"]
result
# Out:
#         treatment year 0  year 6 stumps0 stumps6 difference stumps_diff
# Plot 1        Gap   81.5   549.5    11.5   117.5      468.0       106.0
# Plot 2    Control     84    84.8       5      17        0.8          12
# Plot 3     Radial  261.5  2132.7    16.5   144.5     1871.2       128.0
# Plot 4    Control  136.5     147    15.5      12       10.5        -3.5
# Plot 5     Radial  189.5   510.5       8    89.5      321.0        81.5
# Plot 6    Control  122.5     116     7.5      23       -6.5        15.5
# Plot 7     Radial    280   728.9       6     125      448.9         119
# Plot 8        Gap    239   540.5      10     112      301.5         102
# Plot 9     Radial  141.5     185      15    66.5       43.5        51.5
# Plot 10       Gap  155.7   624.5     8.5   195.5      468.8       187.0
# Plot 11   Control  222.5   273.7      25    54.4       51.2        29.4
# Plot 12       Gap    NaN   810.2     NaN     210        NaN         NaN

# %%
result.to_csv("output.csv")
